# %%
#mounting to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#importing different models
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2125f124-f434-4e28-a40d-9d1fccc1525a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2125f124-f434-4e28-a40d-9d1fccc1525a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# {}

# %%
#importing lib
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision

# %%
H = 256
W = 256


def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

# %%
def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (W, H))
    x = x / 255.0
    x = x.astype(np.float32)
    return x


def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (W, H))
    x = x / 255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)
    return x

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y


def tf_dataset(X, Y, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

# %%
def load_data(path, split=0.2):
    images = sorted(glob(os.path.join(path, "images", "*.tif")))
    masks = sorted(glob(os.path.join(path, "masks", "*.tif")))
    size = int(len(images) * split)

    train_x, test_x = train_test_split(images, test_size=size, random_state=42)
    train_y, test_y = train_test_split(masks, test_size=size, random_state=42)

    split = 0.5
    size = int(len(test_x) * split)

    valid_x, test_x = train_test_split(test_x, test_size=size, random_state=42)
    valid_y, test_y = train_test_split(test_y, test_size=size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

# %%
from modeleditednew2 import build_model #from 'model_name' import build_model 

#Main Function
if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory to save files """
    create_dir("files")

    """ Hyperparaqmeters """
    batch_size = 8
    lr = 1e-4  ## 0.0001
    num_epochs = 10
    model_path = "files/model.h5"
    csv_path = "files/data.csv"

    """ Dataset """
    dataset_path = "/content/drive/MyDrive/Project/Database"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(dataset_path)
    train_x, train_y = shuffle(train_x, train_y)

    print(f"Train: {len(train_x)} - {len(train_y)}")
    print(f"Valid: {len(valid_x)} - {len(valid_y)}")
    print(f"Test: {len(test_x)} - {len(test_y)}")

    train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
    valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

    train_steps = (len(train_x) // batch_size)
    valid_steps = (len(valid_x) // batch_size)

    if len(train_x) % batch_size != 0:
        train_steps += 1

    if len(valid_x) % batch_size != 0:
        valid_steps += 1
# Out:
# Skip1 [<KerasTensor: shape=(None, 128, 128, 8) dtype=float32 (created by layer 'max_pooling2d_24')>, <KerasTensor: shape=(None, 64, 64, 16) dtype=float32 (created by layer 'max_pooling2d_25')>, <KerasTensor: shape=(None, 32, 32, 32) dtype=float32 (created by layer 'max_pooling2d_26')>, <KerasTensor: shape=(None, 16, 16, 64) dtype=float32 (created by layer 'max_pooling2d_27')>, <KerasTensor: shape=(None, 8, 8, 128) dtype=float32 (created by layer 'max_pooling2d_28')>]
# Multiply KerasTensor(type_spec=TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), name='tf.math.multiply_4/Mul:0', description="created by layer 'tf.math.multiply_4'")
# Skip2 [<KerasTensor: shape=(None, 128, 128, 8) dtype=float32 (created by layer 'multiply_37')>, <KerasTensor: shape=(None, 64, 64, 16) dtype=float32 (created by layer 'multiply_38')>, <KerasTensor: shape=(None, 32, 32, 32) dtype=float32 (created by layer 'multiply_39')>, <KerasTensor: shape=(None, 16, 16, 64) dtype=float32 (created by layer 'multiply_40')>, <KerasTensor: shape=(None, 8, 8, 128) dtype=float32 (created by layer 'multiply_41')>]
# Model: "unet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_132 (Conv2D)            (None, 256, 256, 8)  32          ['input_3[0][0]']
#
#  batch_normalization_128 (Batch  (None, 256, 256, 8)  32         ['conv2d_132[0][0]']
#  Normalization)
#
#  activation_122 (Activation)    (None, 256, 256, 8)  0           ['batch_normalization_128[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 256, 256, 8)  584         ['activation_122[0][0]']
#
#  batch_normalization_129 (Batch  (None, 256, 256, 8)  32         ['conv2d_133[0][0]']
#  Normalization)
#
#  activation_123 (Activation)    (None, 256, 256, 8)  0           ['batch_normalization_129[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 256, 256, 8)  72          ['activation_123[0][0]']
#
#  batch_normalization_130 (Batch  (None, 256, 256, 8)  32         ['conv2d_134[0][0]']
#  Normalization)
#
#  conv2d_135 (Conv2D)            (None, 256, 256, 8)  32          ['input_3[0][0]']
#
#  activation_124 (Activation)    (None, 256, 256, 8)  0           ['batch_normalization_130[0][0]']
#
#  batch_normalization_131 (Batch  (None, 256, 256, 8)  32         ['conv2d_135[0][0]']
#  Normalization)
#
#  add_10 (Add)                   (None, 256, 256, 8)  0           ['activation_124[0][0]',
#                                                                   'batch_normalization_131[0][0]']
#
#  max_pooling2d_24 (MaxPooling2D  (None, 128, 128, 8)  0          ['add_10[0][0]']
#  )
#
#  conv2d_136 (Conv2D)            (None, 128, 128, 16  144         ['max_pooling2d_24[0][0]']
#                                 )
#
#  batch_normalization_132 (Batch  (None, 128, 128, 16  64         ['conv2d_136[0][0]']
#  Normalization)                 )
#
#  activation_125 (Activation)    (None, 128, 128, 16  0           ['batch_normalization_132[0][0]']
#                                 )
#
#  conv2d_137 (Conv2D)            (None, 128, 128, 16  2320        ['activation_125[0][0]']
#                                 )
#
#  batch_normalization_133 (Batch  (None, 128, 128, 16  64         ['conv2d_137[0][0]']
#  Normalization)                 )
#
#  activation_126 (Activation)    (None, 128, 128, 16  0           ['batch_normalization_133[0][0]']
#                                 )
#
#  conv2d_138 (Conv2D)            (None, 128, 128, 16  272         ['activation_126[0][0]']
#                                 )
#
#  batch_normalization_134 (Batch  (None, 128, 128, 16  64         ['conv2d_138[0][0]']
#  Normalization)                 )
#
#  conv2d_139 (Conv2D)            (None, 128, 128, 16  144         ['max_pooling2d_24[0][0]']
#                                 )
#
#  activation_127 (Activation)    (None, 128, 128, 16  0           ['batch_normalization_134[0][0]']
#                                 )
#
#  batch_normalization_135 (Batch  (None, 128, 128, 16  64         ['conv2d_139[0][0]']
#  Normalization)                 )
#
#  add_11 (Add)                   (None, 128, 128, 16  0           ['activation_127[0][0]',
#                                 )                                 'batch_normalization_135[0][0]']
#
#  max_pooling2d_25 (MaxPooling2D  (None, 64, 64, 16)  0           ['add_11[0][0]']
#  )
#
#  conv2d_140 (Conv2D)            (None, 64, 64, 32)   544         ['max_pooling2d_25[0][0]']
#
#  batch_normalization_136 (Batch  (None, 64, 64, 32)  128         ['conv2d_140[0][0]']
#  Normalization)
#
#  activation_128 (Activation)    (None, 64, 64, 32)   0           ['batch_normalization_136[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 64, 64, 32)   9248        ['activation_128[0][0]']
#
#  batch_normalization_137 (Batch  (None, 64, 64, 32)  128         ['conv2d_141[0][0]']
#  Normalization)
#
#  activation_129 (Activation)    (None, 64, 64, 32)   0           ['batch_normalization_137[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 64, 64, 32)   1056        ['activation_129[0][0]']
#
#  batch_normalization_138 (Batch  (None, 64, 64, 32)  128         ['conv2d_142[0][0]']
#  Normalization)
#
#  conv2d_143 (Conv2D)            (None, 64, 64, 32)   544         ['max_pooling2d_25[0][0]']
#
#  activation_130 (Activation)    (None, 64, 64, 32)   0           ['batch_normalization_138[0][0]']
#
#  batch_normalization_139 (Batch  (None, 64, 64, 32)  128         ['conv2d_143[0][0]']
#  Normalization)
#
#  add_12 (Add)                   (None, 64, 64, 32)   0           ['activation_130[0][0]',
#                                                                   'batch_normalization_139[0][0]']
#
#  max_pooling2d_26 (MaxPooling2D  (None, 32, 32, 32)  0           ['add_12[0][0]']
#  )
#
#  conv2d_144 (Conv2D)            (None, 32, 32, 64)   2112        ['max_pooling2d_26[0][0]']
#
#  batch_normalization_140 (Batch  (None, 32, 32, 64)  256         ['conv2d_144[0][0]']
#  Normalization)
#
#  activation_131 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_140[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 32, 32, 64)   36928       ['activation_131[0][0]']
#
#  batch_normalization_141 (Batch  (None, 32, 32, 64)  256         ['conv2d_145[0][0]']
#  Normalization)
#
#  activation_132 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_141[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 32, 32, 64)   4160        ['activation_132[0][0]']
#
#  batch_normalization_142 (Batch  (None, 32, 32, 64)  256         ['conv2d_146[0][0]']
#  Normalization)
#
#  conv2d_147 (Conv2D)            (None, 32, 32, 64)   2112        ['max_pooling2d_26[0][0]']
#
#  activation_133 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_142[0][0]']
#
#  batch_normalization_143 (Batch  (None, 32, 32, 64)  256         ['conv2d_147[0][0]']
#  Normalization)
#
#  add_13 (Add)                   (None, 32, 32, 64)   0           ['activation_133[0][0]',
#                                                                   'batch_normalization_143[0][0]']
#
#  max_pooling2d_27 (MaxPooling2D  (None, 16, 16, 64)  0           ['add_13[0][0]']
#  )
#
#  conv2d_148 (Conv2D)            (None, 16, 16, 128)  8320        ['max_pooling2d_27[0][0]']
#
#  batch_normalization_144 (Batch  (None, 16, 16, 128)  512        ['conv2d_148[0][0]']
#  Normalization)
#
#  activation_134 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_144[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 16, 16, 128)  147584      ['activation_134[0][0]']
#
#  batch_normalization_145 (Batch  (None, 16, 16, 128)  512        ['conv2d_149[0][0]']
#  Normalization)
#
#  activation_135 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_145[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 16, 16, 128)  16512       ['activation_135[0][0]']
#
#  batch_normalization_146 (Batch  (None, 16, 16, 128)  512        ['conv2d_150[0][0]']
#  Normalization)
#
#  conv2d_151 (Conv2D)            (None, 16, 16, 128)  8320        ['max_pooling2d_27[0][0]']
#
#  activation_136 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_146[0][0]']
#
#  batch_normalization_147 (Batch  (None, 16, 16, 128)  512        ['conv2d_151[0][0]']
#  Normalization)
#
#  add_14 (Add)                   (None, 16, 16, 128)  0           ['activation_136[0][0]',
#                                                                   'batch_normalization_147[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 1, 1, 128)   0           ['add_14[0][0]']
#  oling2D)
#
#  conv2d_152 (Conv2D)            (None, 1, 1, 64)     8256        ['average_pooling2d_4[0][0]']
#
#  batch_normalization_148 (Batch  (None, 1, 1, 64)    256         ['conv2d_152[0][0]']
#  Normalization)
#
#  conv2d_153 (Conv2D)            (None, 16, 16, 64)   8192        ['add_14[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 16, 16, 64)   73728       ['add_14[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 16, 16, 64)   73728       ['add_14[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 16, 16, 64)   73728       ['add_14[0][0]']
#
#  activation_137 (Activation)    (None, 1, 1, 64)     0           ['batch_normalization_148[0][0]']
#
#  batch_normalization_149 (Batch  (None, 16, 16, 64)  256         ['conv2d_153[0][0]']
#  Normalization)
#
#  batch_normalization_150 (Batch  (None, 16, 16, 64)  256         ['conv2d_154[0][0]']
#  Normalization)
#
#  batch_normalization_151 (Batch  (None, 16, 16, 64)  256         ['conv2d_155[0][0]']
#  Normalization)
#
#  batch_normalization_152 (Batch  (None, 16, 16, 64)  256         ['conv2d_156[0][0]']
#  Normalization)
#
#  up_sampling2d_28 (UpSampling2D  (None, 16, 16, 64)  0           ['activation_137[0][0]']
#  )
#
#  activation_138 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_149[0][0]']
#
#  activation_139 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_150[0][0]']
#
#  activation_140 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_151[0][0]']
#
#  activation_141 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_152[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 16, 16, 320)  0           ['up_sampling2d_28[0][0]',
#                                                                   'activation_138[0][0]',
#                                                                   'activation_139[0][0]',
#                                                                   'activation_140[0][0]',
#                                                                   'activation_141[0][0]']
#
#  max_pooling2d_29 (MaxPooling2D  (None, 4, 4, 320)   0           ['concatenate_24[0][0]']
#  )
#
#  conv2d_157 (Conv2D)            (None, 4, 4, 64)     20480       ['max_pooling2d_29[0][0]']
#
#  batch_normalization_153 (Batch  (None, 4, 4, 64)    256         ['conv2d_157[0][0]']
#  Normalization)
#
#  activation_142 (Activation)    (None, 4, 4, 64)     0           ['batch_normalization_153[0][0]']
#
#  up_sampling2d_29 (UpSampling2D  (None, 8, 8, 64)    0           ['activation_142[0][0]']
#  )
#
#  max_pooling2d_28 (MaxPooling2D  (None, 8, 8, 128)   0           ['add_14[0][0]']
#  )
#
#  concatenate_25 (Concatenate)   (None, 8, 8, 192)    0           ['up_sampling2d_29[0][0]',
#                                                                   'max_pooling2d_28[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 8, 8, 128)    221312      ['concatenate_25[0][0]']
#
#  batch_normalization_154 (Batch  (None, 8, 8, 128)   512         ['conv2d_158[0][0]']
#  Normalization)
#
#  activation_143 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_154[0][0]']
#
#  conv2d_159 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_143[0][0]']
#
#  batch_normalization_155 (Batch  (None, 8, 8, 128)   512         ['conv2d_159[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_155[0][0]']
#
#  conv2d_160 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_144[0][0]']
#
#  batch_normalization_156 (Batch  (None, 8, 8, 128)   512         ['conv2d_160[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_156[0][0]']
#
#  global_average_pooling2d_32 (G  (None, 128)         0           ['activation_145[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_32 (Reshape)           (None, 1, 1, 128)    0           ['global_average_pooling2d_32[0][
#                                                                  0]']
#
#  dense_64 (Dense)               (None, 1, 1, 16)     2048        ['reshape_32[0][0]']
#
#  dense_65 (Dense)               (None, 1, 1, 128)    2048        ['dense_64[0][0]']
#
#  multiply_32 (Multiply)         (None, 8, 8, 128)    0           ['activation_145[0][0]',
#                                                                   'dense_65[0][0]']
#
#  up_sampling2d_30 (UpSampling2D  (None, 16, 16, 128)  0          ['multiply_32[0][0]']
#  )
#
#  concatenate_26 (Concatenate)   (None, 16, 16, 192)  0           ['up_sampling2d_30[0][0]',
#                                                                   'max_pooling2d_27[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 16, 16, 64)   110656      ['concatenate_26[0][0]']
#
#  batch_normalization_157 (Batch  (None, 16, 16, 64)  256         ['conv2d_161[0][0]']
#  Normalization)
#
#  activation_146 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_157[0][0]']
#
#  conv2d_162 (Conv2D)            (None, 16, 16, 64)   36928       ['activation_146[0][0]']
#
#  batch_normalization_158 (Batch  (None, 16, 16, 64)  256         ['conv2d_162[0][0]']
#  Normalization)
#
#  activation_147 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_158[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 16, 16, 64)   36928       ['activation_147[0][0]']
#
#  batch_normalization_159 (Batch  (None, 16, 16, 64)  256         ['conv2d_163[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_159[0][0]']
#
#  global_average_pooling2d_33 (G  (None, 64)          0           ['activation_148[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_33 (Reshape)           (None, 1, 1, 64)     0           ['global_average_pooling2d_33[0][
#                                                                  0]']
#
#  dense_66 (Dense)               (None, 1, 1, 8)      512         ['reshape_33[0][0]']
#
#  dense_67 (Dense)               (None, 1, 1, 64)     512         ['dense_66[0][0]']
#
#  multiply_33 (Multiply)         (None, 16, 16, 64)   0           ['activation_148[0][0]',
#                                                                   'dense_67[0][0]']
#
#  up_sampling2d_31 (UpSampling2D  (None, 32, 32, 64)  0           ['multiply_33[0][0]']
#  )
#
#  concatenate_27 (Concatenate)   (None, 32, 32, 96)   0           ['up_sampling2d_31[0][0]',
#                                                                   'max_pooling2d_26[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 32, 32, 32)   27680       ['concatenate_27[0][0]']
#
#  batch_normalization_160 (Batch  (None, 32, 32, 32)  128         ['conv2d_164[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 32, 32, 32)   0           ['batch_normalization_160[0][0]']
#
#  conv2d_165 (Conv2D)            (None, 32, 32, 32)   9248        ['activation_149[0][0]']
#
#  batch_normalization_161 (Batch  (None, 32, 32, 32)  128         ['conv2d_165[0][0]']
#  Normalization)
#
#  activation_150 (Activation)    (None, 32, 32, 32)   0           ['batch_normalization_161[0][0]']
#
#  conv2d_166 (Conv2D)            (None, 32, 32, 32)   9248        ['activation_150[0][0]']
#
#  batch_normalization_162 (Batch  (None, 32, 32, 32)  128         ['conv2d_166[0][0]']
#  Normalization)
#
#  activation_151 (Activation)    (None, 32, 32, 32)   0           ['batch_normalization_162[0][0]']
#
#  global_average_pooling2d_34 (G  (None, 32)          0           ['activation_151[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_34 (Reshape)           (None, 1, 1, 32)     0           ['global_average_pooling2d_34[0][
#                                                                  0]']
#
#  dense_68 (Dense)               (None, 1, 1, 4)      128         ['reshape_34[0][0]']
#
#  dense_69 (Dense)               (None, 1, 1, 32)     128         ['dense_68[0][0]']
#
#  multiply_34 (Multiply)         (None, 32, 32, 32)   0           ['activation_151[0][0]',
#                                                                   'dense_69[0][0]']
#
#  up_sampling2d_32 (UpSampling2D  (None, 64, 64, 32)  0           ['multiply_34[0][0]']
#  )
#
#  concatenate_28 (Concatenate)   (None, 64, 64, 48)   0           ['up_sampling2d_32[0][0]',
#                                                                   'max_pooling2d_25[0][0]']
#
#  conv2d_167 (Conv2D)            (None, 64, 64, 16)   6928        ['concatenate_28[0][0]']
#
#  batch_normalization_163 (Batch  (None, 64, 64, 16)  64          ['conv2d_167[0][0]']
#  Normalization)
#
#  activation_152 (Activation)    (None, 64, 64, 16)   0           ['batch_normalization_163[0][0]']
#
#  conv2d_168 (Conv2D)            (None, 64, 64, 16)   2320        ['activation_152[0][0]']
#
#  batch_normalization_164 (Batch  (None, 64, 64, 16)  64          ['conv2d_168[0][0]']
#  Normalization)
#
#  activation_153 (Activation)    (None, 64, 64, 16)   0           ['batch_normalization_164[0][0]']
#
#  conv2d_169 (Conv2D)            (None, 64, 64, 16)   2320        ['activation_153[0][0]']
#
#  batch_normalization_165 (Batch  (None, 64, 64, 16)  64          ['conv2d_169[0][0]']
#  Normalization)
#
#  activation_154 (Activation)    (None, 64, 64, 16)   0           ['batch_normalization_165[0][0]']
#
#  global_average_pooling2d_35 (G  (None, 16)          0           ['activation_154[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_35 (Reshape)           (None, 1, 1, 16)     0           ['global_average_pooling2d_35[0][
#                                                                  0]']
#
#  dense_70 (Dense)               (None, 1, 1, 2)      32          ['reshape_35[0][0]']
#
#  dense_71 (Dense)               (None, 1, 1, 16)     32          ['dense_70[0][0]']
#
#  multiply_35 (Multiply)         (None, 64, 64, 16)   0           ['activation_154[0][0]',
#                                                                   'dense_71[0][0]']
#
#  up_sampling2d_33 (UpSampling2D  (None, 128, 128, 16  0          ['multiply_35[0][0]']
#  )                              )
#
#  concatenate_29 (Concatenate)   (None, 128, 128, 24  0           ['up_sampling2d_33[0][0]',
#                                 )                                 'max_pooling2d_24[0][0]']
#
#  conv2d_170 (Conv2D)            (None, 128, 128, 8)  1736        ['concatenate_29[0][0]']
#
#  batch_normalization_166 (Batch  (None, 128, 128, 8)  32         ['conv2d_170[0][0]']
#  Normalization)
#
#  activation_155 (Activation)    (None, 128, 128, 8)  0           ['batch_normalization_166[0][0]']
#
#  conv2d_171 (Conv2D)            (None, 128, 128, 8)  584         ['activation_155[0][0]']
#
#  batch_normalization_167 (Batch  (None, 128, 128, 8)  32         ['conv2d_171[0][0]']
#  Normalization)
#
#  activation_156 (Activation)    (None, 128, 128, 8)  0           ['batch_normalization_167[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 128, 128, 8)  584         ['activation_156[0][0]']
#
#  batch_normalization_168 (Batch  (None, 128, 128, 8)  32         ['conv2d_172[0][0]']
#  Normalization)
#
#  activation_157 (Activation)    (None, 128, 128, 8)  0           ['batch_normalization_168[0][0]']
#
#  global_average_pooling2d_36 (G  (None, 8)           0           ['activation_157[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_36 (Reshape)           (None, 1, 1, 8)      0           ['global_average_pooling2d_36[0][
#                                                                  0]']
#
#  dense_72 (Dense)               (None, 1, 1, 1)      8           ['reshape_36[0][0]']
#
#  dense_73 (Dense)               (None, 1, 1, 8)      8           ['dense_72[0][0]']
#
#  multiply_36 (Multiply)         (None, 128, 128, 8)  0           ['activation_157[0][0]',
#                                                                   'dense_73[0][0]']
#
#  conv2d_173 (Conv2D)            (None, 128, 128, 1)  9           ['multiply_36[0][0]']
#
#  up_sampling2d_34 (UpSampling2D  (None, 256, 256, 1)  0          ['conv2d_173[0][0]']
#  )
#
#  activation_158 (Activation)    (None, 256, 256, 1)  0           ['up_sampling2d_34[0][0]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 256, 256, 3)  0          ['input_3[0][0]',
#  )                                                                'activation_158[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 1, 1, 3)     0           ['tf.math.multiply_4[0][0]']
#  oling2D)
#
#  conv2d_174 (Conv2D)            (None, 1, 1, 64)     256         ['average_pooling2d_5[0][0]']
#
#  batch_normalization_169 (Batch  (None, 1, 1, 64)    256         ['conv2d_174[0][0]']
#  Normalization)
#
#  conv2d_175 (Conv2D)            (None, 256, 256, 64  192         ['tf.math.multiply_4[0][0]']
#                                 )
#
#  conv2d_176 (Conv2D)            (None, 256, 256, 64  1728        ['tf.math.multiply_4[0][0]']
#                                 )
#
#  conv2d_177 (Conv2D)            (None, 256, 256, 64  1728        ['tf.math.multiply_4[0][0]']
#                                 )
#
#  conv2d_178 (Conv2D)            (None, 256, 256, 64  1728        ['tf.math.multiply_4[0][0]']
#                                 )
#
#  activation_159 (Activation)    (None, 1, 1, 64)     0           ['batch_normalization_169[0][0]']
#
#  batch_normalization_170 (Batch  (None, 256, 256, 64  256        ['conv2d_175[0][0]']
#  Normalization)                 )
#
#  batch_normalization_171 (Batch  (None, 256, 256, 64  256        ['conv2d_176[0][0]']
#  Normalization)                 )
#
#  batch_normalization_172 (Batch  (None, 256, 256, 64  256        ['conv2d_177[0][0]']
#  Normalization)                 )
#
#  batch_normalization_173 (Batch  (None, 256, 256, 64  256        ['conv2d_178[0][0]']
#  Normalization)                 )
# ...
#  batch_normalization_197 (Batch  (None, 16, 16, 64)  256         ['conv2d_202[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_197[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 16, 16, 64)   36928       ['activation_187[0][0]']
#
#  batch_normalization_198 (Batch  (None, 16, 16, 64)  256         ['conv2d_203[0][0]']
#  Normalization)
#
#  activation_188 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_198[0][0]']
#
#  global_average_pooling2d_44 (G  (None, 64)          0           ['activation_188[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_44 (Reshape)           (None, 1, 1, 64)     0           ['global_average_pooling2d_44[0][
#                                                                  0]']
#
#  dense_88 (Dense)               (None, 1, 1, 8)      512         ['reshape_44[0][0]']
#
#  dense_89 (Dense)               (None, 1, 1, 64)     512         ['dense_88[0][0]']
#
#  multiply_44 (Multiply)         (None, 16, 16, 64)   0           ['activation_188[0][0]',
#                                                                   'dense_89[0][0]']
#
#  up_sampling2d_38 (UpSampling2D  (None, 32, 32, 64)  0           ['multiply_44[0][0]']
#  )
#
#  concatenate_33 (Concatenate)   (None, 32, 32, 128)  0           ['up_sampling2d_38[0][0]',
#                                                                   'max_pooling2d_26[0][0]',
#                                                                   'multiply_39[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 32, 32, 32)   36896       ['concatenate_33[0][0]']
#
#  batch_normalization_199 (Batch  (None, 32, 32, 32)  128         ['conv2d_204[0][0]']
#  Normalization)
#
#  activation_189 (Activation)    (None, 32, 32, 32)   0           ['batch_normalization_199[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 32, 32, 32)   9248        ['activation_189[0][0]']
#
#  batch_normalization_200 (Batch  (None, 32, 32, 32)  128         ['conv2d_205[0][0]']
#  Normalization)
#
#  activation_190 (Activation)    (None, 32, 32, 32)   0           ['batch_normalization_200[0][0]']
#
#  conv2d_206 (Conv2D)            (None, 32, 32, 32)   9248        ['activation_190[0][0]']
#
#  batch_normalization_201 (Batch  (None, 32, 32, 32)  128         ['conv2d_206[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 32, 32, 32)   0           ['batch_normalization_201[0][0]']
#
#  global_average_pooling2d_45 (G  (None, 32)          0           ['activation_191[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_45 (Reshape)           (None, 1, 1, 32)     0           ['global_average_pooling2d_45[0][
#                                                                  0]']
#
#  dense_90 (Dense)               (None, 1, 1, 4)      128         ['reshape_45[0][0]']
#
#  dense_91 (Dense)               (None, 1, 1, 32)     128         ['dense_90[0][0]']
#
#  multiply_45 (Multiply)         (None, 32, 32, 32)   0           ['activation_191[0][0]',
#                                                                   'dense_91[0][0]']
#
#  up_sampling2d_39 (UpSampling2D  (None, 64, 64, 32)  0           ['multiply_45[0][0]']
#  )
#
#  concatenate_34 (Concatenate)   (None, 64, 64, 64)   0           ['up_sampling2d_39[0][0]',
#                                                                   'max_pooling2d_25[0][0]',
#                                                                   'multiply_38[0][0]']
#
#  conv2d_207 (Conv2D)            (None, 64, 64, 16)   9232        ['concatenate_34[0][0]']
#
#  batch_normalization_202 (Batch  (None, 64, 64, 16)  64          ['conv2d_207[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 64, 64, 16)   0           ['batch_normalization_202[0][0]']
#
#  conv2d_208 (Conv2D)            (None, 64, 64, 16)   2320        ['activation_192[0][0]']
#
#  batch_normalization_203 (Batch  (None, 64, 64, 16)  64          ['conv2d_208[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 64, 64, 16)   0           ['batch_normalization_203[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 64, 64, 16)   2320        ['activation_193[0][0]']
#
#  batch_normalization_204 (Batch  (None, 64, 64, 16)  64          ['conv2d_209[0][0]']
#  Normalization)
#
#  activation_194 (Activation)    (None, 64, 64, 16)   0           ['batch_normalization_204[0][0]']
#
#  global_average_pooling2d_46 (G  (None, 16)          0           ['activation_194[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_46 (Reshape)           (None, 1, 1, 16)     0           ['global_average_pooling2d_46[0][
#                                                                  0]']
#
#  dense_92 (Dense)               (None, 1, 1, 2)      32          ['reshape_46[0][0]']
#
#  dense_93 (Dense)               (None, 1, 1, 16)     32          ['dense_92[0][0]']
#
#  multiply_46 (Multiply)         (None, 64, 64, 16)   0           ['activation_194[0][0]',
#                                                                   'dense_93[0][0]']
#
#  up_sampling2d_40 (UpSampling2D  (None, 128, 128, 16  0          ['multiply_46[0][0]']
#  )                              )
#
#  concatenate_35 (Concatenate)   (None, 128, 128, 32  0           ['up_sampling2d_40[0][0]',
#                                 )                                 'max_pooling2d_24[0][0]',
#                                                                   'multiply_37[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 128, 128, 8)  2312        ['concatenate_35[0][0]']
#
#  batch_normalization_205 (Batch  (None, 128, 128, 8)  32         ['conv2d_210[0][0]']
#  Normalization)
#
#  activation_195 (Activation)    (None, 128, 128, 8)  0           ['batch_normalization_205[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 128, 128, 8)  584         ['activation_195[0][0]']
#
#  batch_normalization_206 (Batch  (None, 128, 128, 8)  32         ['conv2d_211[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 128, 128, 8)  0           ['batch_normalization_206[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 128, 128, 8)  584         ['activation_196[0][0]']
#
#  batch_normalization_207 (Batch  (None, 128, 128, 8)  32         ['conv2d_212[0][0]']
#  Normalization)
#
#  activation_197 (Activation)    (None, 128, 128, 8)  0           ['batch_normalization_207[0][0]']
#
#  global_average_pooling2d_47 (G  (None, 8)           0           ['activation_197[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_47 (Reshape)           (None, 1, 1, 8)      0           ['global_average_pooling2d_47[0][
#                                                                  0]']
#
#  dense_94 (Dense)               (None, 1, 1, 1)      8           ['reshape_47[0][0]']
#
#  dense_95 (Dense)               (None, 1, 1, 8)      8           ['dense_94[0][0]']
#
#  multiply_47 (Multiply)         (None, 128, 128, 8)  0           ['activation_197[0][0]',
#                                                                   'dense_95[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 128, 128, 1)  9           ['multiply_47[0][0]']
#
#  up_sampling2d_41 (UpSampling2D  (None, 256, 256, 1)  0          ['conv2d_213[0][0]']
#  )
#
#  activation_198 (Activation)    (None, 256, 256, 1)  0           ['up_sampling2d_41[0][0]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, 256, 256, 1)  0          ['activation_158[0][0]',
#  )                                                                'activation_198[0][0]']
#
# ==================================================================================================
# Total params: 4,489,386
# Trainable params: 4,479,866
# Non-trainable params: 9,520
# __________________________________________________________________________________________________
# Train: 1584 - 1584
# Valid: 198 - 198
# Test: 197 - 197

# %%
#IoU 
from keras import backend as K

def iou_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)


def iou_coef_loss(y_true, y_pred):
    return -iou_coef(y_true, y_pred)

# %%
#dice coef
from keras.losses import binary_crossentropy
import keras.backend as K

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred = K.cast(y_pred, 'float32')
    y_pred_f = K.cast(K.greater(K.flatten(y_pred), 0.5), 'float32')
    intersection = y_true_f * y_pred_f
    score = 2. * K.sum(intersection) / (K.sum(y_true_f) + K.sum(y_pred_f))
    return score

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. -score

# %%
""" Model """
model = build_model((H, W, 3))
model.compile(optimizer = 'adam', loss = [iou_coef_loss], metrics = [iou_coef])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
    CSVLogger(csv_path),
    EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False)
]

model.fit(
    train_dataset,
    epochs=20,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_steps,
    shuffle = False
    #callbacks=callbacks
)

history = model.history.history
# Out:
# Skip1 [<KerasTensor: shape=(None, 128, 128, 8) dtype=float32 (created by layer 'max_pooling2d_36')>, <KerasTensor: shape=(None, 64, 64, 16) dtype=float32 (created by layer 'max_pooling2d_37')>, <KerasTensor: shape=(None, 32, 32, 32) dtype=float32 (created by layer 'max_pooling2d_38')>, <KerasTensor: shape=(None, 16, 16, 64) dtype=float32 (created by layer 'max_pooling2d_39')>, <KerasTensor: shape=(None, 8, 8, 128) dtype=float32 (created by layer 'max_pooling2d_40')>]
# Multiply KerasTensor(type_spec=TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), name='tf.math.multiply_6/Mul:0', description="created by layer 'tf.math.multiply_6'")
# Skip2 [<KerasTensor: shape=(None, 128, 128, 8) dtype=float32 (created by layer 'multiply_53')>, <KerasTensor: shape=(None, 64, 64, 16) dtype=float32 (created by layer 'multiply_54')>, <KerasTensor: shape=(None, 32, 32, 32) dtype=float32 (created by layer 'multiply_55')>, <KerasTensor: shape=(None, 16, 16, 64) dtype=float32 (created by layer 'multiply_56')>, <KerasTensor: shape=(None, 8, 8, 128) dtype=float32 (created by layer 'multiply_57')>]
# Epoch 1/20
# 198/198 [==============================] - 66s 270ms/step - loss: -0.0745 - iou_coef: 0.0745 - val_loss: -0.0348 - val_iou_coef: 0.0344
# Epoch 2/20
# 198/198 [==============================] - 53s 269ms/step - loss: -0.2777 - iou_coef: 0.2777 - val_loss: -0.2533 - val_iou_coef: 0.2508
# Epoch 3/20
# 198/198 [==============================] - 51s 259ms/step - loss: -0.3587 - iou_coef: 0.3587 - val_loss: -0.3845 - val_iou_coef: 0.3808
# Epoch 4/20
# 198/198 [==============================] - 51s 258ms/step - loss: -0.3908 - iou_coef: 0.3908 - val_loss: -0.3554 - val_iou_coef: 0.3520
# Epoch 5/20
# 198/198 [==============================] - 51s 259ms/step - loss: -0.4114 - iou_coef: 0.4114 - val_loss: -0.3530 - val_iou_coef: 0.3495
# Epoch 6/20
# 198/198 [==============================] - 51s 258ms/step - loss: -0.4140 - iou_coef: 0.4140 - val_loss: -0.3499 - val_iou_coef: 0.3467
# Epoch 7/20
# 198/198 [==============================] - 51s 258ms/step - loss: -0.4291 - iou_coef: 0.4291 - val_loss: -0.4159 - val_iou_coef: 0.4125
# Epoch 8/20
# 198/198 [==============================] - 51s 258ms/step - loss: -0.4181 - iou_coef: 0.4181 - val_loss: -0.3720 - val_iou_coef: 0.3695
# Epoch 9/20
# 198/198 [==============================] - 51s 259ms/step - loss: -0.4456 - iou_coef: 0.4456 - val_loss: -0.4085 - val_iou_coef: 0.4055
# Epoch 10/20
# 198/198 [==============================] - 51s 260ms/step - loss: -0.4707 - iou_coef: 0.4707 - val_loss: -0.3372 - val_iou_coef: 0.3345
# Epoch 11/20
# 198/198 [==============================] - 52s 261ms/step - loss: -0.4450 - iou_coef: 0.4450 - val_loss: -0.4164 - val_iou_coef: 0.4139
# Epoch 12/20
# 198/198 [==============================] - 52s 261ms/step - loss: -0.4503 - iou_coef: 0.4503 - val_loss: -0.4242 - val_iou_coef: 0.4213
# Epoch 13/20
# 198/198 [==============================] - 52s 262ms/step - loss: -0.4590 - iou_coef: 0.4590 - val_loss: -0.4414 - val_iou_coef: 0.4397
# Epoch 14/20
# 198/198 [==============================] - 52s 260ms/step - loss: -0.4753 - iou_coef: 0.4753 - val_loss: -0.4313 - val_iou_coef: 0.4280
# Epoch 15/20
# 198/198 [==============================] - 52s 261ms/step - loss: -0.4884 - iou_coef: 0.4884 - val_loss: -0.4577 - val_iou_coef: 0.4576
# Epoch 16/20
# 198/198 [==============================] - 52s 261ms/step - loss: -0.4918 - iou_coef: 0.4918 - val_loss: -0.4368 - val_iou_coef: 0.4329
# Epoch 17/20
# 198/198 [==============================] - 51s 259ms/step - loss: -0.4836 - iou_coef: 0.4836 - val_loss: -0.4785 - val_iou_coef: 0.4807
# Epoch 18/20
# 198/198 [==============================] - 52s 260ms/step - loss: -0.4699 - iou_coef: 0.4699 - val_loss: -0.1245 - val_iou_coef: 0.1232
# Epoch 19/20
# 198/198 [==============================] - 52s 261ms/step - loss: -0.4564 - iou_coef: 0.4564 - val_loss: -0.4546 - val_iou_coef: 0.4505
# Epoch 20/20
# 198/198 [==============================] - 51s 259ms/step - loss: -0.4936 - iou_coef: 0.4936 - val_loss: -0.4773 - val_iou_coef: 0.4737

# %%
# Plotting the accuracy
import matplotlib.pyplot as plt

train_loss = history['loss']
train_acc = history['iou_coef']

# Performance graph
plt.figure()
plt.plot(train_loss, label='Loss')
plt.plot(train_acc, label='Accuracy')
plt.title('Performance Plot')
plt.legend()
plt.show()

# %%
val_loss = history['val_loss']
val_acc = history['val_iou_coef']

# Performance graph
plt.figure()
plt.plot(val_loss, label='Loss')
plt.plot(val_acc, label='Accuracy')
plt.title('Performance Plot')
plt.legend()
plt.show()

# %%
print("Evaluate on test data")
acc = model.evaluate(valid_dataset)[1] * 100
print('validation Accuracy is:', acc, '%')
# Out:
# Evaluate on test data
# 25/25 [==============================] - 2s 88ms/step - loss: -0.4773 - iou_coef: 0.4737
# validation Accuracy is: 47.36800491809845 %

# %%
test_dataset = tf_dataset(test_x, test_y, batch=batch_size)

print("Evaluate on test data")
results = model.evaluate(test_dataset)[1]*100
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 25/25 [==============================] - 2s 91ms/step - loss: -0.5008 - iou_coef: 0.5005
# test loss, test acc: 50.052839517593384
