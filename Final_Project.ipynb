# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9a1bc41b-5a15-4074-afc8-9b7d3fb1d2ef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a1bc41b-5a15-4074-afc8-9b7d3fb1d2ef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving conv233.py to conv233.py
# {'conv233.py': b'# -*- coding: utf-8 -*-\n"""2conv33.ipynb\n\nAutomatically generated by Colaboratory.\n\nOriginal file is located at\n    https://colab.research.google.com/drive/13k7JZrsa9u8Kgd5WKIiYxUjn2ySaHiUT\n"""\n\nfrom keras.models import Model\nfrom keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout , Activation \nfrom keras.layers import GlobalAveragePooling2D,Dense,Reshape,AveragePooling2D,Multiply,Add\n\ndef squeeze_excite_block(inputs, ratio=8):\n    init = inputs\n    channel_axis = -1\n    filters = init.shape[channel_axis]\n    se_shape = (1, 1, filters)\n\n    se = GlobalAveragePooling2D()(init)\n    se = Reshape(se_shape)(se)\n    se = Dense(filters // ratio, activation=\'relu\', kernel_initializer=\'he_normal\', use_bias=False)(se)\n    se = Dense(filters, activation=\'sigmoid\', kernel_initializer=\'he_normal\', use_bias=False)(se)\n\n    x = Multiply()([init, se])\n    return x\n\n\ndef conv_block(inputs, filters):\n    x = inputs\n\n    x = Conv2D(filters, (3, 3), padding="same")(x)\n    x = BatchNormalization()(x)\n    x = Activation(\'relu\')(x)\n\n    x = Conv2D(filters, (3, 3), padding="same")(x)\n    x = BatchNormalization()(x)\n    x = Activation(\'relu\')(x)\n\n    x = squeeze_excite_block(x)\n\n    return x\n\n\ndef rconv_block(x, n_filter):\n    x_init = x\n    ## Conv 1\n    x = Conv2D(n_filter, (1, 1), padding="same")(x)\n    x = BatchNormalization()(x)\n    x = Activation("relu")(x)\n\n    ## Conv 2\n    x = Conv2D(n_filter, (3, 3), padding="same")(x)\n    x = BatchNormalization()(x)\n    x = Activation("relu")(x)\n\n    ## Conv 3\n    x = Conv2D(n_filter, (1, 1), padding="same")(x)\n    x = BatchNormalization()(x)\n    x = Activation("relu")(x)\n\n    ## Shortcut\n    s = Conv2D(n_filter, (1, 1), padding="same")(x_init)\n    s = BatchNormalization()(s)\n\n    ## Add\n    x = Add()([x, s])\n    return x\n\n\ndef resnet_block(x, n_filter, pool=True):\n    x1 = rconv_block(x, n_filter)\n    c = x1\n\n    ## Pooling\n    if pool == True:\n        x = MaxPooling2D((2, 2), (2, 2))(x1)\n        return c, x\n    else:\n        return c\n\n\ndef encoder1(inputs):\n    num_filters = [8,16, 32, 64, 128]\n    c1, p1 = resnet_block(inputs, num_filters[0])\n    c2, p2 = resnet_block(p1, num_filters[1])\n    c3, p3 = resnet_block(p2, num_filters[2])\n    c4, p4 = resnet_block(p3, num_filters[3])\n    c5, p5 = resnet_block(p4, num_filters[4])\n    skip_connections = [p1, p2, p3, p4, p5]\n    print("Skip1", skip_connections)\n    return p5, skip_connections\n\n\ndef decoder1(inputs, skip_connections):\n    num_filters = [128, 64, 32, 16, 8]\n    skip_connections.reverse()\n    x = inputs\n    print(x)\n\n    for i, f in enumerate(num_filters):\n        x = UpSampling2D((2, 2), interpolation=\'bilinear\')(x)\n        x = concatenate([x, skip_connections[i]])\n        x = conv_block(x, f)\n\n    return x\n\n\ndef encoder2(inputs):\n    num_filters = [8, 16, 32, 64, 128]\n    skip_connections = []\n    x = inputs\n\n    for i, f in enumerate(num_filters):\n        x = conv_block(x, f)\n        skip_connections.append(x)\n        x = MaxPooling2D((2, 2))(x)\n\n    print("Skip2", skip_connections)\n    return x, skip_connections\n\n\ndef decoder2(inputs, skip_1, skip_2):\n    num_filters = [128, 64, 32, 16, 8]\n    skip_2.reverse()\n    x = inputs\n\n    for i, f in enumerate(num_filters):\n        x = UpSampling2D((2, 2), interpolation=\'bilinear\')(x)\n        x = concatenate([x, skip_1[i], skip_2[i]])\n        x = conv_block(x, f)\n\n    return x\n\n\ndef output_block(inputs):\n    x = Conv2D(1, (1, 1), padding="same")(inputs)\n    x = UpSampling2D((2, 2), interpolation=\'bilinear\')(x)\n    x = Activation(\'sigmoid\')(x)\n    return x\n\ndef ASPP(x, filter):\n    shape = x.shape\n\n    y1 = AveragePooling2D(pool_size=(shape[1], shape[2]))(x)\n    y1 = Conv2D(filter, 1, padding="same")(y1)\n    y1 = BatchNormalization()(y1)\n    y1 = Activatio ...

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision

# %%
H = 256
W = 256


def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

# %%
def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (W, H))
    x = x / 255.0
    x = x.astype(np.float32)
    return x


def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (W, H))
    x = x / 255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)
    return x

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y


def tf_dataset(X, Y, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

# %%
def load_data(path, split=0.2):
    images = sorted(glob(os.path.join(path, "images", "*.tif")))
    masks = sorted(glob(os.path.join(path, "masks", "*.tif")))
    size = int(len(images) * split)

    train_x, test_x = train_test_split(images, test_size=size, random_state=42)
    train_y, test_y = train_test_split(masks, test_size=size, random_state=42)

    split = 0.5
    size = int(len(test_x) * split)

    valid_x, test_x = train_test_split(test_x, test_size=size, random_state=42)
    valid_y, test_y = train_test_split(test_y, test_size=size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

# %%
from conv233 import build_model
if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory to save files """
    create_dir("files")

    """ Hyperparaqmeters """
    batch_size = 8
    lr = 1e-4  ## 0.0001
    num_epochs = 10
    model_path = "files/model.h5"
    csv_path = "files/data.csv"

    """ Dataset """
    dataset_path = "/content/drive/MyDrive/Database1"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(dataset_path)
    train_x, train_y = shuffle(train_x, train_y)

    print(f"Train: {len(train_x)} - {len(train_y)}")
    print(f"Valid: {len(valid_x)} - {len(valid_y)}")
    print(f"Test: {len(test_x)} - {len(test_y)}")

    train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
    valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

    train_steps = (len(train_x) // batch_size)
    valid_steps = (len(valid_x) // batch_size)

    if len(train_x) % batch_size != 0:
        train_steps += 1

    if len(valid_x) % batch_size != 0:
        valid_steps += 1
# Out:
# Skip1 [<KerasTensor: shape=(None, 128, 128, 8) dtype=float32 (created by layer 'max_pooling2d')>, <KerasTensor: shape=(None, 64, 64, 16) dtype=float32 (created by layer 'max_pooling2d_1')>, <KerasTensor: shape=(None, 32, 32, 32) dtype=float32 (created by layer 'max_pooling2d_2')>, <KerasTensor: shape=(None, 16, 16, 64) dtype=float32 (created by layer 'max_pooling2d_3')>, <KerasTensor: shape=(None, 8, 8, 128) dtype=float32 (created by layer 'max_pooling2d_4')>]
# KerasTensor(type_spec=TensorSpec(shape=(None, 4, 4, 64), dtype=tf.float32, name=None), name='activation_20/Relu:0', description="created by layer 'activation_20'")
# Multiply KerasTensor(type_spec=TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), name='tf.math.multiply/Mul:0', description="created by layer 'tf.math.multiply'")
# Skip2 [<KerasTensor: shape=(None, 128, 128, 8) dtype=float32 (created by layer 'multiply_5')>, <KerasTensor: shape=(None, 64, 64, 16) dtype=float32 (created by layer 'multiply_6')>, <KerasTensor: shape=(None, 32, 32, 32) dtype=float32 (created by layer 'multiply_7')>, <KerasTensor: shape=(None, 16, 16, 64) dtype=float32 (created by layer 'multiply_8')>, <KerasTensor: shape=(None, 8, 8, 128) dtype=float32 (created by layer 'multiply_9')>]
# Model: "unet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 8)  32          ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 256, 256, 8)  32         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 256, 256, 8)  0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 8)  584         ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 8)  32         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 256, 256, 8)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 8)  72          ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 8)  32         ['conv2d_2[0][0]']
#  rmalization)
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 8)  32          ['input_1[0][0]']
#
#  activation_2 (Activation)      (None, 256, 256, 8)  0           ['batch_normalization_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 8)  32         ['conv2d_3[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 256, 256, 8)  0           ['activation_2[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 8)  0           ['add[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 16  144         ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 16  64         ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 16  2320        ['activation_3[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 16  64         ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  activation_4 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 128, 128, 16  272         ['activation_4[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 128, 128, 16  64         ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  conv2d_7 (Conv2D)              (None, 128, 128, 16  144         ['max_pooling2d[0][0]']
#                                 )
#
#  activation_5 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 128, 128, 16  64         ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  add_1 (Add)                    (None, 128, 128, 16  0           ['activation_5[0][0]',
#                                 )                                 'batch_normalization_7[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 16)  0           ['add_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 32)   544         ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 32)   9248        ['activation_6[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 32)   1056        ['activation_7[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 32)  128         ['conv2d_10[0][0]']
#  ormalization)
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 32)   544         ['max_pooling2d_1[0][0]']
#
#  activation_8 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 32)  128         ['conv2d_11[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 64, 64, 32)   0           ['activation_8[0][0]',
#                                                                   'batch_normalization_11[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 32)  0           ['add_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 64)   2112        ['max_pooling2d_2[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_9 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_9[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 64)   4160        ['activation_10[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 64)  256         ['conv2d_14[0][0]']
#  ormalization)
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 64)   2112        ['max_pooling2d_2[0][0]']
#
#  activation_11 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 64)  256         ['conv2d_15[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 32, 32, 64)   0           ['activation_11[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 64)  0           ['add_3[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 16, 16, 128)  8320        ['max_pooling2d_3[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 16, 16, 128)  512        ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_12[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 16, 16, 128)  512        ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 16, 16, 128)  16512       ['activation_13[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 16, 16, 128)  512        ['conv2d_18[0][0]']
#  ormalization)
#
#  conv2d_19 (Conv2D)             (None, 16, 16, 128)  8320        ['max_pooling2d_3[0][0]']
#
#  activation_14 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 16, 16, 128)  512        ['conv2d_19[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 16, 16, 128)  0           ['activation_14[0][0]',
#                                                                   'batch_normalization_19[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 128)   0           ['add_4[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 128)   0           ['max_pooling2d_4[0][0]']
#  ing2D)
#
#  conv2d_20 (Conv2D)             (None, 1, 1, 64)     8256        ['average_pooling2d[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 1, 1, 64)    256         ['conv2d_20[0][0]']
#  ormalization)
#
#  conv2d_21 (Conv2D)             (None, 8, 8, 64)     8192        ['max_pooling2d_4[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 8, 8, 64)     73728       ['max_pooling2d_4[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 8, 8, 64)     73728       ['max_pooling2d_4[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 8, 8, 64)     73728       ['max_pooling2d_4[0][0]']
#
#  activation_15 (Activation)     (None, 1, 1, 64)     0           ['batch_normalization_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 8, 8, 64)    256         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 8, 8, 64)    256         ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 8, 8, 64)    256         ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 8, 8, 64)    256         ['conv2d_24[0][0]']
#  ormalization)
#
#  up_sampling2d (UpSampling2D)   (None, 8, 8, 64)     0           ['activation_15[0][0]']
#
#  activation_16 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_21[0][0]']
#
#  activation_17 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_22[0][0]']
#
#  activation_18 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_23[0][0]']
#
#  activation_19 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_24[0][0]']
#
#  concatenate (Concatenate)      (None, 8, 8, 320)    0           ['up_sampling2d[0][0]',
#                                                                   'activation_16[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]',
#                                                                   'activation_19[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 320)   0           ['concatenate[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 4, 4, 64)     20480       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 4, 4, 64)    256         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 4, 4, 64)     0           ['batch_normalization_25[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 8, 8, 64)    0           ['activation_20[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 192)    0           ['up_sampling2d_1[0][0]',
#                                                                   'max_pooling2d_4[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 8, 8, 128)    221312      ['concatenate_1[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 8, 8, 128)   512         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 8, 8, 128)    147584      ['activation_21[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 8, 8, 128)   512         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_27[0][0]']
#
#  global_average_pooling2d (Glob  (None, 128)         0           ['activation_22[0][0]']
#  alAveragePooling2D)
#
#  reshape (Reshape)              (None, 1, 1, 128)    0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 1, 1, 16)     2048        ['reshape[0][0]']
#
#  dense_1 (Dense)                (None, 1, 1, 128)    2048        ['dense[0][0]']
#
#  multiply (Multiply)            (None, 8, 8, 128)    0           ['activation_22[0][0]',
#                                                                   'dense_1[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 16, 16, 128)  0          ['multiply[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 16, 16, 192)  0           ['up_sampling2d_2[0][0]',
#                                                                   'max_pooling2d_3[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 16, 16, 64)   110656      ['concatenate_2[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 64)  256         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 16, 16, 64)   36928       ['activation_23[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 64)  256         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_29[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 64)          0           ['activation_24[0][0]']
#  obalAveragePooling2D)
#
#  reshape_1 (Reshape)            (None, 1, 1, 64)     0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_2 (Dense)                (None, 1, 1, 8)      512         ['reshape_1[0][0]']
#
#  dense_3 (Dense)                (None, 1, 1, 64)     512         ['dense_2[0][0]']
#
#  multiply_1 (Multiply)          (None, 16, 16, 64)   0           ['activation_24[0][0]',
#                                                                   'dense_3[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 32, 32, 64)  0           ['multiply_1[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 32, 32, 96)   0           ['up_sampling2d_3[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 32)   27680       ['concatenate_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 32)  128         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 32, 32, 32)   9248        ['activation_25[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 32, 32, 32)  128         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_31[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 32)          0           ['activation_26[0][0]']
#  obalAveragePooling2D)
#
#  reshape_2 (Reshape)            (None, 1, 1, 32)     0           ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  dense_4 (Dense)                (None, 1, 1, 4)      128         ['reshape_2[0][0]']
#
#  dense_5 (Dense)                (None, 1, 1, 32)     128         ['dense_4[0][0]']
#
#  multiply_2 (Multiply)          (None, 32, 32, 32)   0           ['activation_26[0][0]',
#                                                                   'dense_5[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 64, 64, 32)  0           ['multiply_2[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 64, 64, 48)   0           ['up_sampling2d_4[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 64, 64, 16)   6928        ['concatenate_4[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 64, 64, 16)  64          ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 64, 64, 16)   0           ['batch_normalization_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 64, 64, 16)   2320        ['activation_27[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 64, 64, 16)  64          ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 64, 64, 16)   0           ['batch_normalization_33[0][0]']
#
#  global_average_pooling2d_3 (Gl  (None, 16)          0           ['activation_28[0][0]']
#  obalAveragePooling2D)
#
#  reshape_3 (Reshape)            (None, 1, 1, 16)     0           ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  dense_6 (Dense)                (None, 1, 1, 2)      32          ['reshape_3[0][0]']
#
#  dense_7 (Dense)                (None, 1, 1, 16)     32          ['dense_6[0][0]']
#
#  multiply_3 (Multiply)          (None, 64, 64, 16)   0           ['activation_28[0][0]',
#                                                                   'dense_7[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 128, 128, 16  0          ['multiply_3[0][0]']
#                                 )
#
#  concatenate_5 (Concatenate)    (None, 128, 128, 24  0           ['up_sampling2d_5[0][0]',
#                                 )                                 'max_pooling2d[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 128, 128, 8)  1736        ['concatenate_5[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 128, 128, 8)  32         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 128, 128, 8)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 128, 128, 8)  584         ['activation_29[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 128, 128, 8)  32         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 128, 128, 8)  0           ['batch_normalization_35[0][0]']
#
#  global_average_pooling2d_4 (Gl  (None, 8)           0           ['activation_30[0][0]']
#  obalAveragePooling2D)
#
#  reshape_4 (Reshape)            (None, 1, 1, 8)      0           ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  dense_8 (Dense)                (None, 1, 1, 1)      8           ['reshape_4[0][0]']
#
#  dense_9 (Dense)                (None, 1, 1, 8)      8           ['dense_8[0][0]']
#
#  multiply_4 (Multiply)          (None, 128, 128, 8)  0           ['activation_30[0][0]',
#                                                                   'dense_9[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 128, 128, 1)  9           ['multiply_4[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 256, 256, 1)  0          ['conv2d_36[0][0]']
#
#  activation_31 (Activation)     (None, 256, 256, 1)  0           ['up_sampling2d_6[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 256, 256, 3)  0           ['input_1[0][0]',
#                                                                   'activation_31[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 128, 128, 3)  0          ['tf.math.multiply[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 128, 128, 8)  224         ['max_pooling2d_6[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 128, 128, 8)  32         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 128, 128, 8)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 128, 128, 8)  584         ['activation_32[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 128, 128, 8)  32         ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 128, 128, 8)  0           ['batch_normalization_37[0][0]']
#
#  global_average_pooling2d_5 (Gl  (None, 8)           0           ['activation_33[0][0]']
#  obalAveragePooling2D)
#
#  reshape_5 (Reshape)            (None, 1, 1, 8)      0           ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  dense_10 (Dense)               (None, 1, 1, 1)      8           ['reshape_5[0][0]']
#
#  dense_11 (Dense)               (None, 1, 1, 8)      8           ['dense_10[0][0]']
#
#  multiply_5 (Multiply)          (None, 128, 128, 8)  0           ['activation_33[0][0]',
#                                                                   'dense_11[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 64, 64, 8)   0           ['multiply_5[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 64, 64, 16)   1168        ['max_pooling2d_7[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 64, 64, 16)  64          ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 64, 64, 16)   0           ['batch_normalization_38[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 64, 64, 16)   2320        ['activation_34[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 64, 64, 16)  64          ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 64, 64, 16)   0           ['batch_normalization_39[0][0]']
#
#  global_average_pooling2d_6 (Gl  (None, 16)          0           ['activation_35[0][0]']
#  obalAveragePooling2D)
#
#  reshape_6 (Reshape)            (None, 1, 1, 16)     0           ['global_average_pooling2d_6[0][0
#                                                                  ]']
#
#  dense_12 (Dense)               (None, 1, 1, 2)      32          ['reshape_6[0][0]']
#
#  dense_13 (Dense)               (None, 1, 1, 16)     32          ['dense_12[0][0]']
#
#  multiply_6 (Multiply)          (None, 64, 64, 16)   0           ['activation_35[0][0]',
#                                                                   'dense_13[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 32, 32, 16)  0           ['multiply_6[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 32, 32, 32)   4640        ['max_pooling2d_8[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 32, 32, 32)  128         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_40[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 32, 32, 32)   9248        ['activation_36[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 32, 32, 32)  128         ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_41[0][0]']
#
#  global_average_pooling2d_7 (Gl  (None, 32)          0           ['activation_37[0][0]']
#  obalAveragePooling2D)
#
#  reshape_7 (Reshape)            (None, 1, 1, 32)     0           ['global_average_pooling2d_7[0][0
#                                                                  ]']
# ...
#
#  global_average_pooling2d_11 (G  (None, 128)         0           ['activation_45[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_11 (Reshape)           (None, 1, 1, 128)    0           ['global_average_pooling2d_11[0][
#                                                                  0]']
#
#  dense_22 (Dense)               (None, 1, 1, 16)     2048        ['reshape_11[0][0]']
#
#  dense_23 (Dense)               (None, 1, 1, 128)    2048        ['dense_22[0][0]']
#
#  multiply_11 (Multiply)         (None, 8, 8, 128)    0           ['activation_45[0][0]',
#                                                                   'dense_23[0][0]']
#
#  up_sampling2d_8 (UpSampling2D)  (None, 16, 16, 128)  0          ['multiply_11[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 16, 16, 256)  0           ['up_sampling2d_8[0][0]',
#                                                                   'max_pooling2d_3[0][0]',
#                                                                   'multiply_8[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 16, 16, 64)   147520      ['concatenate_7[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 16, 16, 64)  256         ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_50[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 16, 16, 64)   36928       ['activation_46[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 16, 16, 64)  256         ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_51[0][0]']
#
#  global_average_pooling2d_12 (G  (None, 64)          0           ['activation_47[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_12 (Reshape)           (None, 1, 1, 64)     0           ['global_average_pooling2d_12[0][
#                                                                  0]']
#
#  dense_24 (Dense)               (None, 1, 1, 8)      512         ['reshape_12[0][0]']
#
#  dense_25 (Dense)               (None, 1, 1, 64)     512         ['dense_24[0][0]']
#
#  multiply_12 (Multiply)         (None, 16, 16, 64)   0           ['activation_47[0][0]',
#                                                                   'dense_25[0][0]']
#
#  up_sampling2d_9 (UpSampling2D)  (None, 32, 32, 64)  0           ['multiply_12[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 32, 32, 128)  0           ['up_sampling2d_9[0][0]',
#                                                                   'max_pooling2d_2[0][0]',
#                                                                   'multiply_7[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 32, 32, 32)   36896       ['concatenate_8[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 32, 32, 32)  128         ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_52[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 32, 32, 32)   9248        ['activation_48[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 32, 32, 32)  128         ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_53[0][0]']
#
#  global_average_pooling2d_13 (G  (None, 32)          0           ['activation_49[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_13 (Reshape)           (None, 1, 1, 32)     0           ['global_average_pooling2d_13[0][
#                                                                  0]']
#
#  dense_26 (Dense)               (None, 1, 1, 4)      128         ['reshape_13[0][0]']
#
#  dense_27 (Dense)               (None, 1, 1, 32)     128         ['dense_26[0][0]']
#
#  multiply_13 (Multiply)         (None, 32, 32, 32)   0           ['activation_49[0][0]',
#                                                                   'dense_27[0][0]']
#
#  up_sampling2d_10 (UpSampling2D  (None, 64, 64, 32)  0           ['multiply_13[0][0]']
#  )
#
#  concatenate_9 (Concatenate)    (None, 64, 64, 64)   0           ['up_sampling2d_10[0][0]',
#                                                                   'max_pooling2d_1[0][0]',
#                                                                   'multiply_6[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 64, 64, 16)   9232        ['concatenate_9[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 64, 64, 16)  64          ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 64, 64, 16)   0           ['batch_normalization_54[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 64, 64, 16)   2320        ['activation_50[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 64, 64, 16)  64          ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 64, 64, 16)   0           ['batch_normalization_55[0][0]']
#
#  global_average_pooling2d_14 (G  (None, 16)          0           ['activation_51[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_14 (Reshape)           (None, 1, 1, 16)     0           ['global_average_pooling2d_14[0][
#                                                                  0]']
#
#  dense_28 (Dense)               (None, 1, 1, 2)      32          ['reshape_14[0][0]']
#
#  dense_29 (Dense)               (None, 1, 1, 16)     32          ['dense_28[0][0]']
#
#  multiply_14 (Multiply)         (None, 64, 64, 16)   0           ['activation_51[0][0]',
#                                                                   'dense_29[0][0]']
#
#  up_sampling2d_11 (UpSampling2D  (None, 128, 128, 16  0          ['multiply_14[0][0]']
#  )                              )
#
#  concatenate_10 (Concatenate)   (None, 128, 128, 32  0           ['up_sampling2d_11[0][0]',
#                                 )                                 'max_pooling2d[0][0]',
#                                                                   'multiply_5[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 128, 128, 8)  2312        ['concatenate_10[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 128, 128, 8)  32         ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 128, 128, 8)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 128, 128, 8)  584         ['activation_52[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 128, 128, 8)  32         ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 128, 128, 8)  0           ['batch_normalization_57[0][0]']
#
#  global_average_pooling2d_15 (G  (None, 8)           0           ['activation_53[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_15 (Reshape)           (None, 1, 1, 8)      0           ['global_average_pooling2d_15[0][
#                                                                  0]']
#
#  dense_30 (Dense)               (None, 1, 1, 1)      8           ['reshape_15[0][0]']
#
#  dense_31 (Dense)               (None, 1, 1, 8)      8           ['dense_30[0][0]']
#
#  multiply_15 (Multiply)         (None, 128, 128, 8)  0           ['activation_53[0][0]',
#                                                                   'dense_31[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 128, 128, 1)  9           ['multiply_15[0][0]']
#
#  up_sampling2d_12 (UpSampling2D  (None, 256, 256, 1)  0          ['conv2d_59[0][0]']
#  )
#
#  activation_54 (Activation)     (None, 256, 256, 1)  0           ['up_sampling2d_12[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 256, 256, 1)  0          ['activation_31[0][0]',
#  )                                                                'activation_54[0][0]']
#
# ==================================================================================================
# Total params: 3,273,274
# Trainable params: 3,266,522
# Non-trainable params: 6,752
# __________________________________________________________________________________________________
# Train: 1584 - 1584
# Valid: 198 - 198
# Test: 197 - 197

# %%
from keras import backend as K

def iou_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)


def iou_coef_loss(y_true, y_pred):
    return -iou_coef(y_true, y_pred)

# %%
from keras.losses import binary_crossentropy
import keras.backend as K

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred = K.cast(y_pred, 'float32')
    y_pred_f = K.cast(K.greater(K.flatten(y_pred), 0.5), 'float32')
    intersection = y_true_f * y_pred_f
    score = 2. * K.sum(intersection) / (K.sum(y_true_f) + K.sum(y_pred_f))
    return score

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. -score

# %%
""" Model """
model = build_model((H, W, 3))
model.compile(optimizer = 'adamax', loss = [iou_coef_loss], metrics = [iou_coef])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
    CSVLogger(csv_path),
    EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False)
]

model.fit(
    train_dataset,
    epochs=20,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_steps,
    shuffle = False
    #callbacks=callbacks
)

history = model.history.history
# Out:
# Skip1 [<KerasTensor: shape=(None, 128, 128, 8) dtype=float32 (created by layer 'max_pooling2d_12')>, <KerasTensor: shape=(None, 64, 64, 16) dtype=float32 (created by layer 'max_pooling2d_13')>, <KerasTensor: shape=(None, 32, 32, 32) dtype=float32 (created by layer 'max_pooling2d_14')>, <KerasTensor: shape=(None, 16, 16, 64) dtype=float32 (created by layer 'max_pooling2d_15')>, <KerasTensor: shape=(None, 8, 8, 128) dtype=float32 (created by layer 'max_pooling2d_16')>]
# KerasTensor(type_spec=TensorSpec(shape=(None, 4, 4, 64), dtype=tf.float32, name=None), name='activation_75/Relu:0', description="created by layer 'activation_75'")
# Multiply KerasTensor(type_spec=TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), name='tf.math.multiply_2/Mul:0', description="created by layer 'tf.math.multiply_2'")
# Skip2 [<KerasTensor: shape=(None, 128, 128, 8) dtype=float32 (created by layer 'multiply_21')>, <KerasTensor: shape=(None, 64, 64, 16) dtype=float32 (created by layer 'multiply_22')>, <KerasTensor: shape=(None, 32, 32, 32) dtype=float32 (created by layer 'multiply_23')>, <KerasTensor: shape=(None, 16, 16, 64) dtype=float32 (created by layer 'multiply_24')>, <KerasTensor: shape=(None, 8, 8, 128) dtype=float32 (created by layer 'multiply_25')>]
# Epoch 1/20
# 198/198 [==============================] - 294s 1s/step - loss: -0.0484 - iou_coef: 0.0484 - val_loss: -0.0164 - val_iou_coef: 0.0163
# Epoch 2/20
# 198/198 [==============================] - 61s 308ms/step - loss: -0.0862 - iou_coef: 0.0862 - val_loss: -0.0593 - val_iou_coef: 0.0587
# Epoch 3/20
# 198/198 [==============================] - 61s 307ms/step - loss: -0.1438 - iou_coef: 0.1438 - val_loss: -0.1190 - val_iou_coef: 0.1178
# Epoch 4/20
# 198/198 [==============================] - 61s 307ms/step - loss: -0.2315 - iou_coef: 0.2315 - val_loss: -0.2166 - val_iou_coef: 0.2144
# Epoch 5/20
# 198/198 [==============================] - 61s 307ms/step - loss: -0.3285 - iou_coef: 0.3285 - val_loss: -0.3406 - val_iou_coef: 0.3372
# Epoch 6/20
# 198/198 [==============================] - 61s 306ms/step - loss: -0.4151 - iou_coef: 0.4151 - val_loss: -0.4122 - val_iou_coef: 0.4080
# Epoch 7/20
# 198/198 [==============================] - 61s 307ms/step - loss: -0.4663 - iou_coef: 0.4663 - val_loss: -0.4464 - val_iou_coef: 0.4420
# Epoch 8/20
# 198/198 [==============================] - 61s 306ms/step - loss: -0.4961 - iou_coef: 0.4961 - val_loss: -0.4234 - val_iou_coef: 0.4192
# Epoch 9/20
# 198/198 [==============================] - 61s 307ms/step - loss: -0.5164 - iou_coef: 0.5164 - val_loss: -0.4699 - val_iou_coef: 0.4653
# Epoch 10/20
# 198/198 [==============================] - 61s 306ms/step - loss: -0.5359 - iou_coef: 0.5359 - val_loss: -0.4757 - val_iou_coef: 0.4709
# Epoch 11/20
# 198/198 [==============================] - 61s 306ms/step - loss: -0.5508 - iou_coef: 0.5508 - val_loss: -0.4865 - val_iou_coef: 0.4817
# Epoch 12/20
# 198/198 [==============================] - 61s 306ms/step - loss: -0.5514 - iou_coef: 0.5514 - val_loss: -0.4632 - val_iou_coef: 0.4586
# Epoch 13/20
# 198/198 [==============================] - 61s 305ms/step - loss: -0.5644 - iou_coef: 0.5644 - val_loss: -0.5010 - val_iou_coef: 0.4960
# Epoch 14/20
# 198/198 [==============================] - 61s 307ms/step - loss: -0.5784 - iou_coef: 0.5784 - val_loss: -0.5060 - val_iou_coef: 0.5009
# Epoch 15/20
# 198/198 [==============================] - 61s 307ms/step - loss: -0.5786 - iou_coef: 0.5786 - val_loss: -0.4975 - val_iou_coef: 0.4925
# Epoch 16/20
# 198/198 [==============================] - 61s 307ms/step - loss: -0.5833 - iou_coef: 0.5833 - val_loss: -0.4993 - val_iou_coef: 0.4948
# Epoch 17/20
# 198/198 [==============================] - 61s 307ms/step - loss: -0.5924 - iou_coef: 0.5924 - val_loss: -0.5182 - val_iou_coef: 0.5130
# Epoch 18/20
# 198/198 [==============================] - 61s 306ms/step - loss: -0.5921 - iou_coef: 0.5921 - val_loss: -0.5143 - val_iou_coef: 0.5092
# Epoch 19/20
# 198/198 [==============================] - 61s 306ms/step - loss: -0.5948 - iou_coef: 0.5948 - val_loss: -0.5156 - val_iou_coef: 0.5105
# Epoch 20/20
# 198/198 [==============================] - 61s 307ms/step - loss: -0.5915 - iou_coef: 0.5915 - val_loss: -0.5034 - val_iou_coef: 0.4984

# %%
# Plotting the accuracy
import matplotlib.pyplot as plt

train_loss = history['loss']
train_acc = history['iou_coef']

# Performance graph
plt.figure()
plt.plot(train_loss, label='Loss')
plt.plot(train_acc, label='Accuracy')
plt.title('Performance Plot')
plt.legend()
plt.show()

# %%
val_loss = history['val_loss']
val_acc = history['val_iou_coef']

# Performance graph
plt.figure()
plt.plot(val_loss, label='Loss')
plt.plot(val_acc, label='Accuracy')
plt.title('Performance Plot')
plt.legend()
plt.show()

# %%
print("Evaluate on test data")
acc = model.evaluate(valid_dataset)[1] * 100
print('validation Accuracy is:', acc, '%')
# Out:
# Evaluate on test data
# 25/25 [==============================] - 3s 108ms/step - loss: -0.5034 - iou_coef: 0.4984
# validation Accuracy is: 49.84053671360016 %

# %%
test_dataset = tf_dataset(test_x, test_y, batch=batch_size)

print("Evaluate on test data")
results = model.evaluate(test_dataset)[1]*100
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 25/25 [==============================] - 31s 1s/step - loss: -0.5551 - iou_coef: 0.5566
# test loss, test acc: 55.65793514251709
